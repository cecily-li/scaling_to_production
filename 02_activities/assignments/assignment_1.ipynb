# %% [markdown]
# # Working with parquet files
#
# ## Objective
#
# + In this assignment, we will use the data downloaded with the module `data_manager` to create features.
#
# (11 pts total)
#
# ## Prerequisites
#
# + This notebook assumes that price data is available to you in the environment variable `PRICE_DATA`. If you have not done so, then execute the notebook `production_2_data_engineering.ipynb` to create this data set.

# %% [markdown]
# + Load the environment variables using dotenv. (1 pt)

# %%
# Write your code below.
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
import dask.dataframe as dd

# %% [markdown]
# + Load the environment variable `PRICE_DATA`.
# + Use [glob](https://docs.python.org/3/library/glob.html) to find the path of all parquet files in the directory `PRICE_DATA`.
#
# (1pt)

# %%
import os
from glob import glob

# Write your code below.

PRICE_DATA = os.getenv("PRICE_DATA")
parquet_files = glob(os.path.join(PRICE_DATA, "*/*.parquet"))

parquet_files
# Out:
# ['../../05_src/data/prices/CTAS/CTAS_2008.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2018.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2011.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2001.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2000.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2010.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2019.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2009.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2012.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2002.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2024.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2003.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2013.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2016.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2006.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2020.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2021.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2007.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2017.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2023.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2015.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2005.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2004.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2014.parquet',
#  '../../05_src/data/prices/CTAS/CTAS_2022.parquet',
#  '../../05_src/data/prices/WELL/WELL_2021.parquet',
#  '../../05_src/data/prices/WELL/WELL_2007.parquet',
#  '../../05_src/data/prices/WELL/WELL_2017.parquet',
#  '../../05_src/data/prices/WELL/WELL_2016.parquet',
#  '../../05_src/data/prices/WELL/WELL_2006.parquet',
#  '../../05_src/data/prices/WELL/WELL_2020.parquet',
#  '../../05_src/data/prices/WELL/WELL_2004.parquet',
#  '../../05_src/data/prices/WELL/WELL_2014.parquet',
#  '../../05_src/data/prices/WELL/WELL_2022.parquet',
#  '../../05_src/data/prices/WELL/WELL_2023.parquet',
#  '../../05_src/data/prices/WELL/WELL_2015.parquet',
#  '../../05_src/data/prices/WELL/WELL_2005.parquet',
#  '../../05_src/data/prices/WELL/WELL_2000.parquet',
#  '../../05_src/data/prices/WELL/WELL_2010.parquet',
#  '../../05_src/data/prices/WELL/WELL_2019.parquet',
#  '../../05_src/data/prices/WELL/WELL_2009.parquet',
#  '../../05_src/data/prices/WELL/WELL_2008.parquet',
#  '../../05_src/data/prices/WELL/WELL_2018.parquet',
#  '../../05_src/data/prices/WELL/WELL_2011.parquet',
#  '../../05_src/data/prices/WELL/WELL_2001.parquet',
#  '../../05_src/data/prices/WELL/WELL_2003.parquet',
#  '../../05_src/data/prices/WELL/WELL_2013.parquet',
#  '../../05_src/data/prices/WELL/WELL_2012.parquet',
#  '../../05_src/data/prices/WELL/WELL_2002.parquet',
#  '../../05_src/data/prices/WELL/WELL_2024.parquet',
#  '../../05_src/data/prices/VZ/VZ_2001.parquet',
#  '../../05_src/data/prices/VZ/VZ_2011.parquet',
#  '../../05_src/data/prices/VZ/VZ_2018.parquet',
#  '../../05_src/data/prices/VZ/VZ_2008.parquet',
#  '../../05_src/data/prices/VZ/VZ_2009.parquet',
#  '../../05_src/data/prices/VZ/VZ_2019.parquet',
#  '../../05_src/data/prices/VZ/VZ_2010.parquet',
#  '../../05_src/data/prices/VZ/VZ_2000.parquet',
#  '../../05_src/data/prices/VZ/VZ_2024.parquet',
#  '../../05_src/data/prices/VZ/VZ_2002.parquet',
#  '../../05_src/data/prices/VZ/VZ_2012.parquet',
#  '../../05_src/data/prices/VZ/VZ_2013.parquet',
#  '../../05_src/data/prices/VZ/VZ_2003.parquet',
#  '../../05_src/data/prices/VZ/VZ_2020.parquet',
#  '../../05_src/data/prices/VZ/VZ_2006.parquet',
#  '../../05_src/data/prices/VZ/VZ_2016.parquet',
#  '../../05_src/data/prices/VZ/VZ_2017.parquet',
#  '../../05_src/data/prices/VZ/VZ_2007.parquet',
#  '../../05_src/data/prices/VZ/VZ_2021.parquet',
#  '../../05_src/data/prices/VZ/VZ_2005.parquet',
#  '../../05_src/data/prices/VZ/VZ_2015.parquet',
#  '../../05_src/data/prices/VZ/VZ_2023.parquet',
#  '../../05_src/data/prices/VZ/VZ_2022.parquet',
#  '../../05_src/data/prices/VZ/VZ_2014.parquet',
#  '../../05_src/data/prices/VZ/VZ_2004.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2023.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2015.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2005.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2004.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2014.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2022.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2016.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2006.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2020.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2021.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2007.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2017.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2012.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2002.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2024.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2003.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2013.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2008.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2018.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2011.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2001.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2000.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2010.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2019.parquet',
#  '../../05_src/data/prices/AMZN/AMZN_2009.parquet',
#  '../../05_src/data/prices/CNP/CNP_2010.parquet',
#  '../../05_src/data/prices/CNP/CNP_2000.parquet',
#  '../../05_src/data/prices/CNP/CNP_2009.parquet',
#  '../../05_src/data/prices/CNP/CNP_2019.parquet',
#  '../../05_src/data/prices/CNP/CNP_2018.parquet',
#  '../../05_src/data/prices/CNP/CNP_2008.parquet',
#  '../../05_src/data/prices/CNP/CNP_2001.parquet',
#  '../../05_src/data/prices/CNP/CNP_2011.parquet',
#  '../../05_src/data/prices/CNP/CNP_2013.parquet',
#  '../../05_src/data/prices/CNP/CNP_2003.parquet',
#  '../../05_src/data/prices/CNP/CNP_2002.parquet',
#  '../../05_src/data/prices/CNP/CNP_2012.parquet',
#  '../../05_src/data/prices/CNP/CNP_2024.parquet',
#  '../../05_src/data/prices/CNP/CNP_2021.parquet',
#  '../../05_src/data/prices/CNP/CNP_2017.parquet',
#  '../../05_src/data/prices/CNP/CNP_2007.parquet',
#  '../../05_src/data/prices/CNP/CNP_2006.parquet',
#  '../../05_src/data/prices/CNP/CNP_2016.parquet',
#  '../../05_src/data/prices/CNP/CNP_2020.parquet',
#  '../../05_src/data/prices/CNP/CNP_2014.parquet',
#  '../../05_src/data/prices/CNP/CNP_2004.parquet',
#  '../../05_src/data/prices/CNP/CNP_2022.parquet',
#  '../../05_src/data/prices/CNP/CNP_2023.parquet',
#  '../../05_src/data/prices/CNP/CNP_2005.parquet',
#  '../../05_src/data/prices/CNP/CNP_2015.parquet',
#  '../../05_src/data/prices/RCL/RCL_2000.parquet',
#  '../../05_src/data/prices/RCL/RCL_2010.parquet',
#  '../../05_src/data/prices/RCL/RCL_2019.parquet',
#  '../../05_src/data/prices/RCL/RCL_2009.parquet',
#  '../../05_src/data/prices/RCL/RCL_2008.parquet',
#  '../../05_src/data/prices/RCL/RCL_2018.parquet',
#  '../../05_src/data/prices/RCL/RCL_2011.parquet',
#  '../../05_src/data/prices/RCL/RCL_2001.parquet',
#  '../../05_src/data/prices/RCL/RCL_2003.parquet',
#  '../../05_src/data/prices/RCL/RCL_2013.parquet',
#  '../../05_src/data/prices/RCL/RCL_2012.parquet',
#  '../../05_src/data/prices/RCL/RCL_2002.parquet',
#  '../../05_src/data/prices/RCL/RCL_2024.parquet',
#  '../../05_src/data/prices/RCL/RCL_2021.parquet',
#  '../../05_src/data/prices/RCL/RCL_2007.parquet',
#  '../../05_src/data/prices/RCL/RCL_2017.parquet',
#  '../../05_src/data/prices/RCL/RCL_2016.parquet',
#  '../../05_src/data/prices/RCL/RCL_2006.parquet',
#  '../../05_src/data/prices/RCL/RCL_2020.parquet',
#  '../../05_src/data/prices/RCL/RCL_2004.parquet',
#  '../../05_src/data/prices/RCL/RCL_2014.parquet',
#  '../../05_src/data/prices/RCL/RCL_2022.parquet',
#  '../../05_src/data/prices/RCL/RCL_2023.parquet',
#  '../../05_src/data/prices/RCL/RCL_2015.parquet',
#  '../../05_src/data/prices/RCL/RCL_2005.parquet',
#  '../../05_src/data/prices/CAT/CAT_2013.parquet',
#  '../../05_src/data/prices/CAT/CAT_2003.parquet',
#  '../../05_src/data/prices/CAT/CAT_2024.parquet',
#  '../../05_src/data/prices/CAT/CAT_2002.parquet',
#  '../../05_src/data/prices/CAT/CAT_2012.parquet',
#  '../../05_src/data/prices/CAT/CAT_2009.parquet',
#  '../../05_src/data/prices/CAT/CAT_2019.parquet',
#  '../../05_src/data/prices/CAT/CAT_2010.parquet',
#  '../../05_src/data/prices/CAT/CAT_2000.parquet',
#  '../../05_src/data/prices/CAT/CAT_2001.parquet',
#  '../../05_src/data/prices/CAT/CAT_2011.parquet',
#  '../../05_src/data/prices/CAT/CAT_2018.parquet',
#  '../../05_src/data/prices/CAT/CAT_2008.parquet',
#  '../../05_src/data/prices/CAT/CAT_2022.parquet',
#  '../../05_src/data/prices/CAT/CAT_2014.parquet',
#  '../../05_src/data/prices/CAT/CAT_2004.parquet',
#  '../../05_src/data/prices/CAT/CAT_2005.parquet',
#  '../../05_src/data/prices/CAT/CAT_2015.parquet',
#  '../../05_src/data/prices/CAT/CAT_2023.parquet',
#  '../../05_src/data/prices/CAT/CAT_2017.parquet',
#  '../../05_src/data/prices/CAT/CAT_2007.parquet',
#  '../../05_src/data/prices/CAT/CAT_2021.parquet',
#  '../../05_src/data/prices/CAT/CAT_2020.parquet',
#  '../../05_src/data/prices/CAT/CAT_2006.parquet',
#  '../../05_src/data/prices/CAT/CAT_2016.parquet',
#  '../../05_src/data/prices/TFC/TFC_2003.parquet',
#  '../../05_src/data/prices/TFC/TFC_2013.parquet',
#  '../../05_src/data/prices/TFC/TFC_2024.parquet',
#  '../../05_src/data/prices/TFC/TFC_2012.parquet',
#  '../../05_src/data/prices/TFC/TFC_2002.parquet',
#  '../../05_src/data/prices/TFC/TFC_2019.parquet',
#  '../../05_src/data/prices/TFC/TFC_2009.parquet',
#  '../../05_src/data/prices/TFC/TFC_2000.parquet',
#  '../../05_src/data/prices/TFC/TFC_2010.parquet',
#  '../../05_src/data/prices/TFC/TFC_2011.parquet',
#  '../../05_src/data/prices/TFC/TFC_2001.parquet',
#  '../../05_src/data/prices/TFC/TFC_2008.parquet',
#  '../../05_src/data/prices/TFC/TFC_2018.parquet',
#  '../../05_src/data/prices/TFC/TFC_2022.parquet',
#  '../../05_src/data/prices/TFC/TFC_2004.parquet',
#  '../../05_src/data/prices/TFC/TFC_2014.parquet',
#  '../../05_src/data/prices/TFC/TFC_2015.parquet',
#  '../../05_src/data/prices/TFC/TFC_2005.parquet',
#  '../../05_src/data/prices/TFC/TFC_2023.parquet',
#  '../../05_src/data/prices/TFC/TFC_2007.parquet',
#  '../../05_src/data/prices/TFC/TFC_2017.parquet',
#  '../../05_src/data/prices/TFC/TFC_2021.parquet',
#  '../../05_src/data/prices/TFC/TFC_2020.parquet',
#  '../../05_src/data/prices/TFC/TFC_2016.parquet',
#  '../../05_src/data/prices/TFC/TFC_2006.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2018.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2008.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2001.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2011.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2010.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2000.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2009.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2019.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2002.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2012.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2024.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2013.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2003.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2006.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2016.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2020.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2021.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2017.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2007.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2023.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2005.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2015.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2014.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2004.parquet',
#  '../../05_src/data/prices/AAPL/AAPL_2022.parquet',
#  '../../05_src/data/prices/PANW/PANW_2023.parquet',
#  '../../05_src/data/prices/PANW/PANW_2015.parquet',
#  '../../05_src/data/prices/PANW/PANW_2014.parquet',
#  '../../05_src/data/prices/PANW/PANW_2022.parquet',
#  '../../05_src/data/prices/PANW/PANW_2016.parquet',
#  '../../05_src/data/prices/PANW/PANW_2020.parquet',
#  '../../05_src/data/prices/PANW/PANW_2021.parquet',
#  '../../05_src/data/prices/PANW/PANW_2017.parquet',
#  '../../05_src/data/prices/PANW/PANW_2012.parquet',
#  '../../05_src/data/prices/PANW/PANW_2024.parquet',
#  '../../05_src/data/prices/PANW/PANW_2013.parquet',
#  '../../05_src/data/prices/PANW/PANW_2018.parquet',
#  '../../05_src/data/prices/PANW/PANW_2019.parquet',
#  '../../05_src/data/prices/PM/PM_2012.parquet',
#  '../../05_src/data/prices/PM/PM_2024.parquet',
#  '../../05_src/data/prices/PM/PM_2013.parquet',
#  '../../05_src/data/prices/PM/PM_2008.parquet',
#  '../../05_src/data/prices/PM/PM_2018.parquet',
#  '../../05_src/data/prices/PM/PM_2011.parquet',
#  '../../05_src/data/prices/PM/PM_2010.parquet',
#  '../../05_src/data/prices/PM/PM_2019.parquet',
#  '../../05_src/data/prices/PM/PM_2009.parquet',
#  '../../05_src/data/prices/PM/PM_2023.parquet',
#  '../../05_src/data/prices/PM/PM_2015.parquet',
#  '../../05_src/data/prices/PM/PM_2014.parquet',
#  '../../05_src/data/prices/PM/PM_2022.parquet',
#  '../../05_src/data/prices/PM/PM_2016.parquet',
#  '../../05_src/data/prices/PM/PM_2020.parquet',
#  '../../05_src/data/prices/PM/PM_2021.parquet',
#  '../../05_src/data/prices/PM/PM_2017.parquet',
#  '../../05_src/data/prices/KHC/KHC_2017.parquet',
#  '../../05_src/data/prices/KHC/KHC_2021.parquet',
#  '../../05_src/data/prices/KHC/KHC_2020.parquet',
#  '../../05_src/data/prices/KHC/KHC_2016.parquet',
#  '../../05_src/data/prices/KHC/KHC_2022.parquet',
#  '../../05_src/data/prices/KHC/KHC_2015.parquet',
#  '../../05_src/data/prices/KHC/KHC_2023.parquet',
#  '../../05_src/data/prices/KHC/KHC_2019.parquet',
#  '../../05_src/data/prices/KHC/KHC_2018.parquet',
#  '../../05_src/data/prices/KHC/KHC_2024.parquet',
#  '../../05_src/data/prices/TEL/TEL_2015.parquet',
#  '../../05_src/data/prices/TEL/TEL_2023.parquet',
#  '../../05_src/data/prices/TEL/TEL_2022.parquet',
#  '../../05_src/data/prices/TEL/TEL_2014.parquet',
#  '../../05_src/data/prices/TEL/TEL_2020.parquet',
#  '../../05_src/data/prices/TEL/TEL_2016.parquet',
#  '../../05_src/data/prices/TEL/TEL_2017.parquet',
#  '../../05_src/data/prices/TEL/TEL_2007.parquet',
#  '../../05_src/data/prices/TEL/TEL_2021.parquet',
#  '../../05_src/data/prices/TEL/TEL_2024.parquet',
#  '../../05_src/data/prices/TEL/TEL_2012.parquet',
#  '../../05_src/data/prices/TEL/TEL_2013.parquet',
#  '../../05_src/data/prices/TEL/TEL_2011.parquet',
#  '../../05_src/data/prices/TEL/TEL_2018.parquet',
#  '../../05_src/data/prices/TEL/TEL_2008.parquet',
#  '../../05_src/data/prices/TEL/TEL_2009.parquet',
#  '../../05_src/data/prices/TEL/TEL_2019.parquet',
#  '../../05_src/data/prices/TEL/TEL_2010.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2017.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2007.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2021.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2020.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2006.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2016.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2022.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2014.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2004.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2005.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2015.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2023.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2009.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2019.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2010.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2000.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2001.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2011.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2018.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2008.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2013.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2003.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2024.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2002.parquet',
#  '../../05_src/data/prices/CMCSA/CMCSA_2012.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2014.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2004.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2022.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2023.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2005.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2015.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2021.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2017.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2007.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2006.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2016.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2020.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2013.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2003.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2002.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2012.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2024.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2010.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2000.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2009.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2019.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2018.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2008.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2001.parquet',
#  '../../05_src/data/prices/GRMN/GRMN_2011.parquet',
#  '../../05_src/data/prices/ANET/ANET_2018.parquet',
#  '../../05_src/data/prices/ANET/ANET_2019.parquet',
#  '../../05_src/data/prices/ANET/ANET_2024.parquet',
#  '../../05_src/data/prices/ANET/ANET_2020.parquet',
#  '../../05_src/data/prices/ANET/ANET_2016.parquet',
#  '../../05_src/data/prices/ANET/ANET_2017.parquet',
#  '../../05_src/data/prices/ANET/ANET_2021.parquet',
#  '../../05_src/data/prices/ANET/ANET_2015.parquet',
#  '../../05_src/data/prices/ANET/ANET_2023.parquet',
#  '../../05_src/data/prices/ANET/ANET_2022.parquet',
#  '../../05_src/data/prices/ANET/ANET_2014.parquet',
#  '../../05_src/data/prices/BRO/BRO_2024.parquet',
#  '../../05_src/data/prices/BRO/BRO_2012.parquet',
#  '../../05_src/data/prices/BRO/BRO_2002.parquet',
#  '../../05_src/data/prices/BRO/BRO_2003.parquet',
#  '../../05_src/data/prices/BRO/BRO_2013.parquet',
#  '../../05_src/data/prices/BRO/BRO_2011.parquet',
#  '../../05_src/data/prices/BRO/BRO_2001.parquet',
#  '../../05_src/data/prices/BRO/BRO_2008.parquet',
#  '../../05_src/data/prices/BRO/BRO_2018.parquet',
#  '../../05_src/data/prices/BRO/BRO_2019.parquet',
#  '../../05_src/data/prices/BRO/BRO_2009.parquet',
#  '../../05_src/data/prices/BRO/BRO_2000.parquet',
#  '../../05_src/data/prices/BRO/BRO_2010.parquet',
#  '../../05_src/data/prices/BRO/BRO_2015.parquet',
#  '../../05_src/data/prices/BRO/BRO_2005.parquet',
#  '../../05_src/data/prices/BRO/BRO_2023.parquet',
#  '../../05_src/data/prices/BRO/BRO_2022.parquet',
#  '../../05_src/data/prices/BRO/BRO_2004.parquet',
#  '../../05_src/data/prices/BRO/BRO_2014.parquet',
#  '../../05_src/data/prices/BRO/BRO_2020.parquet',
#  '../../05_src/data/prices/BRO/BRO_2016.parquet',
#  '../../05_src/data/prices/BRO/BRO_2006.parquet',
#  '../../05_src/data/prices/BRO/BRO_2007.parquet',
#  '../../05_src/data/prices/BRO/BRO_2017.parquet',
#  '../../05_src/data/prices/BRO/BRO_2021.parquet',
#  '../../05_src/data/prices/CAH/CAH_2021.parquet',
#  '../../05_src/data/prices/CAH/CAH_2007.parquet',
#  '../../05_src/data/prices/CAH/CAH_2017.parquet',
#  '../../05_src/data/prices/CAH/CAH_2016.parquet',
#  '../../05_src/data/prices/CAH/CAH_2006.parquet',
#  '../../05_src/data/prices/CAH/CAH_2020.parquet',
#  '../../05_src/data/prices/CAH/CAH_2004.parquet',
#  '../../05_src/data/prices/CAH/CAH_2014.parquet',
#  '../../05_src/data/prices/CAH/CAH_2022.parquet',
#  '../../05_src/data/prices/CAH/CAH_2023.parquet',
#  '../../05_src/data/prices/CAH/CAH_2015.parquet',
#  '../../05_src/data/prices/CAH/CAH_2005.parquet',
#  '../../05_src/data/prices/CAH/CAH_2000.parquet',
#  '../../05_src/data/prices/CAH/CAH_2010.parquet',
#  '../../05_src/data/prices/CAH/CAH_2019.parquet',
#  '../../05_src/data/prices/CAH/CAH_2009.parquet',
#  '../../05_src/data/prices/CAH/CAH_2008.parquet',
#  '../../05_src/data/prices/CAH/CAH_2018.parquet',
#  '../../05_src/data/prices/CAH/CAH_2011.parquet',
#  '../../05_src/data/prices/CAH/CAH_2001.parquet',
#  '../../05_src/data/prices/CAH/CAH_2003.parquet',
#  '../../05_src/data/prices/CAH/CAH_2013.parquet',
#  '../../05_src/data/prices/CAH/CAH_2012.parquet',
#  '../../05_src/data/prices/CAH/CAH_2002.parquet',
#  '../../05_src/data/prices/CAH/CAH_2024.parquet',
#  '../../05_src/data/prices/TROW/TROW_2024.parquet',
#  '../../05_src/data/prices/TROW/TROW_2002.parquet',
#  '../../05_src/data/prices/TROW/TROW_2012.parquet',
#  '../../05_src/data/prices/TROW/TROW_2013.parquet',
#  '../../05_src/data/prices/TROW/TROW_2003.parquet',
#  '../../05_src/data/prices/TROW/TROW_2001.parquet',
#  '../../05_src/data/prices/TROW/TROW_2011.parquet',
#  '../../05_src/data/prices/TROW/TROW_2018.parquet',
#  '../../05_src/data/prices/TROW/TROW_2008.parquet',
#  '../../05_src/data/prices/TROW/TROW_2009.parquet',
#  '../../05_src/data/prices/TROW/TROW_2019.parquet',
#  '../../05_src/data/prices/TROW/TROW_2010.parquet',
#  '../../05_src/data/prices/TROW/TROW_2000.parquet',
#  '../../05_src/data/prices/TROW/TROW_2005.parquet',
#  '../../05_src/data/prices/TROW/TROW_2015.parquet',
#  '../../05_src/data/prices/TROW/TROW_2023.parquet',
#  '../../05_src/data/prices/TROW/TROW_2022.parquet',
#  '../../05_src/data/prices/TROW/TROW_2014.parquet',
#  '../../05_src/data/prices/TROW/TROW_2004.parquet',
#  '../../05_src/data/prices/TROW/TROW_2020.parquet',
#  '../../05_src/data/prices/TROW/TROW_2006.parquet',
#  '../../05_src/data/prices/TROW/TROW_2016.parquet',
#  '../../05_src/data/prices/TROW/TROW_2017.parquet',
#  '../../05_src/data/prices/TROW/TROW_2007.parquet',
#  '../../05_src/data/prices/TROW/TROW_2021.parquet',
#  '../../05_src/data/prices/PODD/PODD_2015.parquet',
#  '../../05_src/data/prices/PODD/PODD_2023.parquet',
#  '../../05_src/data/prices/PODD/PODD_2022.parquet',
#  '../../05_src/data/prices/PODD/PODD_2014.parquet',
#  '../../05_src/data/prices/PODD/PODD_2020.parquet',
#  '../../05_src/data/prices/PODD/PODD_2016.parquet',
#  '../../05_src/data/prices/PODD/PODD_2007.parquet',
#  '../../05_src/data/prices/PODD/PODD_2017.parquet',
#  '../../05_src/data/prices/PODD/PODD_2021.parquet',
#  '../../05_src/data/prices/PODD/PODD_2024.parquet',
#  '../../05_src/data/prices/PODD/PODD_2012.parquet',
#  '../../05_src/data/prices/PODD/PODD_2013.parquet',
#  '../../05_src/data/prices/PODD/PODD_2011.parquet',
#  '../../05_src/data/prices/PODD/PODD_2008.parquet',
#  '../../05_src/data/prices/PODD/PODD_2018.parquet',
#  '../../05_src/data/prices/PODD/PODD_2019.parquet',
#  '../../05_src/data/prices/PODD/PODD_2009.parquet',
#  '../../05_src/data/prices/PODD/PODD_2010.parquet',
#  '../../05_src/data/prices/FSLR/FSLR_2016.parquet',
#  '../../05_src/data/prices/FSLR/FSLR_2006.parquet',
#  '../../05_src/data/prices/FSLR/FSLR_2020.parquet',
#  '../../05_src/data/prices/FSLR/FSLR_2021.parquet',
#  '../../05_src/data/prices/FSLR/FSLR_2007.parquet',
#  '../../05_src/data/prices/FSLR/FSLR_2017.parquet',
#  '../../05_src/data/prices/FSLR/FSLR_2023.parquet',
#  '../../05_src/data/prices/FSLR/FSLR_2015.parquet',
#  '../../05_src/data/prices/FSLR/FSLR_2014.parquet',
#  '../../05_src/data/prices/FSLR/FSLR_2022.parquet',
#  '../../05_src/data/prices/FSLR/FSLR_2008.parquet',
#  '../../05_src/data/prices/FSLR/FSLR_2018.parquet',
#  '../../05_src/data/prices/FSLR/FSLR_2011.parquet',
#  '../../05_src/data/prices/FSLR/FSLR_2010.parquet',
#  '../../05_src/data/prices/FSLR/FSLR_2019.parquet',
#  '../../05_src/data/prices/FSLR/FSLR_2009.parquet',
#  '../../05_src/data/prices/FSLR/FSLR_2012.parquet',
#  '../../05_src/data/prices/FSLR/FSLR_2024.parquet',
#  '../../05_src/data/prices/FSLR/FSLR_2013.parquet',
#  '../../05_src/data/prices/PFE/PFE_2018.parquet',
#  '../../05_src/data/prices/PFE/PFE_2008.parquet',
#  '../../05_src/data/prices/PFE/PFE_2001.parquet',
#  '../../05_src/data/prices/PFE/PFE_2011.parquet',
#  '../../05_src/data/prices/PFE/PFE_2010.parquet',
#  '../../05_src/data/prices/PFE/PFE_2000.parquet',
#  '../../05_src/data/prices/PFE/PFE_2009.parquet',
#  '../../05_src/data/prices/PFE/PFE_2019.parquet',
#  '../../05_src/data/prices/PFE/PFE_2002.parquet',
#  '../../05_src/data/prices/PFE/PFE_2012.parquet',
#  '../../05_src/data/prices/PFE/PFE_2024.parquet',
#  '../../05_src/data/prices/PFE/PFE_2013.parquet',
#  '../../05_src/data/prices/PFE/PFE_2003.parquet',
#  '../../05_src/data/prices/PFE/PFE_2006.parquet',
#  '../../05_src/data/prices/PFE/PFE_2016.parquet',
#  '../../05_src/data/prices/PFE/PFE_2020.parquet',
#  '../../05_src/data/prices/PFE/PFE_2021.parquet',
#  '../../05_src/data/prices/PFE/PFE_2017.parquet',
#  '../../05_src/data/prices/PFE/PFE_2007.parquet',
#  '../../05_src/data/prices/PFE/PFE_2023.parquet',
#  '../../05_src/data/prices/PFE/PFE_2005.parquet',
#  '../../05_src/data/prices/PFE/PFE_2015.parquet',
#  '../../05_src/data/prices/PFE/PFE_2014.parquet',
#  '../../05_src/data/prices/PFE/PFE_2004.parquet',
#  '../../05_src/data/prices/PFE/PFE_2022.parquet',
#  '../../05_src/data/prices/REG/REG_2021.parquet',
#  '../../05_src/data/prices/REG/REG_2007.parquet',
#  '../../05_src/data/prices/REG/REG_2017.parquet',
#  '../../05_src/data/prices/REG/REG_2016.parquet',
#  '../../05_src/data/prices/REG/REG_2006.parquet',
#  '../../05_src/data/prices/REG/REG_2020.parquet',
#  '../../05_src/data/prices/REG/REG_2004.parquet',
#  '../../05_src/data/prices/REG/REG_2014.parquet',
#  '../../05_src/data/prices/REG/REG_2022.parquet',
#  '../../05_src/data/prices/REG/REG_2023.parquet',
#  '../../05_src/data/prices/REG/REG_2015.parquet',
#  '../../05_src/data/prices/REG/REG_2005.parquet',
#  '../../05_src/data/prices/REG/REG_2000.parquet',
#  '../../05_src/data/prices/REG/REG_2010.parquet',
#  '../../05_src/data/prices/REG/REG_2019.parquet',
#  '../../05_src/data/prices/REG/REG_2009.parquet',
#  '../../05_src/data/prices/REG/REG_2008.parquet',
#  '../../05_src/data/prices/REG/REG_2018.parquet',
#  '../../05_src/data/prices/REG/REG_2011.parquet',
#  '../../05_src/data/prices/REG/REG_2001.parquet',
#  '../../05_src/data/prices/REG/REG_2003.parquet',
#  '../../05_src/data/prices/REG/REG_2013.parquet',
#  '../../05_src/data/prices/REG/REG_2012.parquet',
#  '../../05_src/data/prices/REG/REG_2002.parquet',
#  '../../05_src/data/prices/REG/REG_2024.parquet',
#  '../../05_src/data/prices/TFX/TFX_2021.parquet',
#  '../../05_src/data/prices/TFX/TFX_2017.parquet',
#  '../../05_src/data/prices/TFX/TFX_2007.parquet',
#  '../../05_src/data/prices/TFX/TFX_2006.parquet',
#  '../../05_src/data/prices/TFX/TFX_2016.parquet',
#  '../../05_src/data/prices/TFX/TFX_2020.parquet',
#  '../../05_src/data/prices/TFX/TFX_2014.parquet',
#  '../../05_src/data/prices/TFX/TFX_2004.parquet',
#  '../../05_src/data/prices/TFX/TFX_2022.parquet',
#  '../../05_src/data/prices/TFX/TFX_2023.parquet',
#  '../../05_src/data/prices/TFX/TFX_2005.parquet',
#  '../../05_src/data/prices/TFX/TFX_2015.parquet',
#  '../../05_src/data/prices/TFX/TFX_2010.parquet',
#  '../../05_src/data/prices/TFX/TFX_2000.parquet',
#  '../../05_src/data/prices/TFX/TFX_2009.parquet',
#  '../../05_src/data/prices/TFX/TFX_2019.parquet',
#  '../../05_src/data/prices/TFX/TFX_2018.parquet',
#  '../../05_src/data/prices/TFX/TFX_2008.parquet',
#  '../../05_src/data/prices/TFX/TFX_2001.parquet',
#  '../../05_src/data/prices/TFX/TFX_2011.parquet',
#  '../../05_src/data/prices/TFX/TFX_2013.parquet',
#  '../../05_src/data/prices/TFX/TFX_2003.parquet',
#  '../../05_src/data/prices/TFX/TFX_2002.parquet',
#  '../../05_src/data/prices/TFX/TFX_2012.parquet',
#  '../../05_src/data/prices/TFX/TFX_2024.parquet',
#  '../../05_src/data/prices/APTV/APTV_2013.parquet',
#  '../../05_src/data/prices/APTV/APTV_2012.parquet',
#  '../../05_src/data/prices/APTV/APTV_2024.parquet',
#  '../../05_src/data/prices/APTV/APTV_2019.parquet',
#  '../../05_src/data/prices/APTV/APTV_2018.parquet',
#  '../../05_src/data/prices/APTV/APTV_2011.parquet',
#  '../../05_src/data/prices/APTV/APTV_2014.parquet',
#  '../../05_src/data/prices/APTV/APTV_2022.parquet',
#  '../../05_src/data/prices/APTV/APTV_2023.parquet',
#  '../../05_src/data/prices/APTV/APTV_2015.parquet',
#  '../../05_src/data/prices/APTV/APTV_2021.parquet',
#  '../../05_src/data/prices/APTV/APTV_2017.parquet',
#  '../../05_src/data/prices/APTV/APTV_2016.parquet',
#  '../../05_src/data/prices/APTV/APTV_2020.parquet',
#  '../../05_src/data/prices/AAL/AAL_2011.parquet',
#  '../../05_src/data/prices/AAL/AAL_2008.parquet',
#  '../../05_src/data/prices/AAL/AAL_2018.parquet',
#  '../../05_src/data/prices/AAL/AAL_2019.parquet',
#  '../../05_src/data/prices/AAL/AAL_2009.parquet',
#  '../../05_src/data/prices/AAL/AAL_2010.parquet',
#  '../../05_src/data/prices/AAL/AAL_2024.parquet',
#  '../../05_src/data/prices/AAL/AAL_2012.parquet',
#  '../../05_src/data/prices/AAL/AAL_2013.parquet',
#  '../../05_src/data/prices/AAL/AAL_2020.parquet',
#  '../../05_src/data/prices/AAL/AAL_2016.parquet',
#  '../../05_src/data/prices/AAL/AAL_2006.parquet',
#  '../../05_src/data/prices/AAL/AAL_2007.parquet',
#  '../../05_src/data/prices/AAL/AAL_2017.parquet',
#  '../../05_src/data/prices/AAL/AAL_2021.parquet',
#  '../../05_src/data/prices/AAL/AAL_2015.parquet',
#  '../../05_src/data/prices/AAL/AAL_2005.parquet',
#  '../../05_src/data/prices/AAL/AAL_2023.parquet',
#  '../../05_src/data/prices/AAL/AAL_2022.parquet',
#  '../../05_src/data/prices/AAL/AAL_2014.parquet',
#  '../../05_src/data/prices/CDW/CDW_2024.parquet',
#  '../../05_src/data/prices/CDW/CDW_2013.parquet',
#  '../../05_src/data/prices/CDW/CDW_2018.parquet',
#  '../../05_src/data/prices/CDW/CDW_2019.parquet',
#  '../../05_src/data/prices/CDW/CDW_2015.parquet',
#  '../../05_src/data/prices/CDW/CDW_2023.parquet',
#  '../../05_src/data/prices/CDW/CDW_2022.parquet',
#  '../../05_src/data/prices/CDW/CDW_2014.parquet',
#  '../../05_src/data/prices/CDW/CDW_2020.parquet',
#  '../../05_src/data/prices/CDW/CDW_2016.parquet',
#  '../../05_src/data/prices/CDW/CDW_2017.parquet',
#  '../../05_src/data/prices/CDW/CDW_2021.parquet',
#  '../../05_src/data/prices/MAR/MAR_2013.parquet',
#  '../../05_src/data/prices/MAR/MAR_2003.parquet',
#  '../../05_src/data/prices/MAR/MAR_2024.parquet',
#  '../../05_src/data/prices/MAR/MAR_2002.parquet',
#  '../../05_src/data/prices/MAR/MAR_2012.parquet',
#  '../../05_src/data/prices/MAR/MAR_2009.parquet',
#  '../../05_src/data/prices/MAR/MAR_2019.parquet',
#  '../../05_src/data/prices/MAR/MAR_2010.parquet',
#  '../../05_src/data/prices/MAR/MAR_2000.parquet',
#  '../../05_src/data/prices/MAR/MAR_2001.parquet',
#  '../../05_src/data/prices/MAR/MAR_2011.parquet',
#  '../../05_src/data/prices/MAR/MAR_2018.parquet',
#  '../../05_src/data/prices/MAR/MAR_2008.parquet',
#  '../../05_src/data/prices/MAR/MAR_2022.parquet',
#  '../../05_src/data/prices/MAR/MAR_2014.parquet',
#  '../../05_src/data/prices/MAR/MAR_2004.parquet',
#  '../../05_src/data/prices/MAR/MAR_2005.parquet',
#  '../../05_src/data/prices/MAR/MAR_2015.parquet',
#  '../../05_src/data/prices/MAR/MAR_2023.parquet',
#  '../../05_src/data/prices/MAR/MAR_2017.parquet',
#  '../../05_src/data/prices/MAR/MAR_2007.parquet',
#  '../../05_src/data/prices/MAR/MAR_2021.parquet',
#  '../../05_src/data/prices/MAR/MAR_2020.parquet',
#  '../../05_src/data/prices/MAR/MAR_2006.parquet',
#  '../../05_src/data/prices/MAR/MAR_2016.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2022.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2014.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2004.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2005.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2015.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2023.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2017.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2007.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2021.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2020.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2006.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2016.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2013.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2003.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2024.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2002.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2012.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2009.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2019.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2010.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2000.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2001.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2011.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2018.parquet',
#  '../../05_src/data/prices/VRSN/VRSN_2008.parquet',
#  '../../05_src/data/prices/FITB/FITB_2016.parquet',
#  '../../05_src/data/prices/FITB/FITB_2006.parquet',
#  '../../05_src/data/prices/FITB/FITB_2020.parquet',
#  '../../05_src/data/prices/FITB/FITB_2021.parquet',
#  '../../05_src/data/prices/FITB/FITB_2007.parquet',
#  '../../05_src/data/prices/FITB/FITB_2017.parquet',
#  '../../05_src/data/prices/FITB/FITB_2023.parquet',
#  '../../05_src/data/prices/FITB/FITB_2015.parquet',
#  '../../05_src/data/prices/FITB/FITB_2005.parquet',
#  '../../05_src/data/prices/FITB/FITB_2004.parquet',
#  '../../05_src/data/prices/FITB/FITB_2014.parquet',
#  '../../05_src/data/prices/FITB/FITB_2022.parquet',
#  '../../05_src/data/prices/FITB/FITB_2008.parquet',
#  '../../05_src/data/prices/FITB/FITB_2018.parquet',
#  '../../05_src/data/prices/FITB/FITB_2011.parquet',
#  '../../05_src/data/prices/FITB/FITB_2001.parquet',
#  '../../05_src/data/prices/FITB/FITB_2000.parquet',
#  '../../05_src/data/prices/FITB/FITB_2010.parquet',
#  '../../05_src/data/prices/FITB/FITB_2019.parquet',
#  '../../05_src/data/prices/FITB/FITB_2009.parquet',
#  '../../05_src/data/prices/FITB/FITB_2012.parquet',
#  '../../05_src/data/prices/FITB/FITB_2002.parquet',
#  '../../05_src/data/prices/FITB/FITB_2024.parquet',
#  '../../05_src/data/prices/FITB/FITB_2003.parquet',
#  '../../05_src/data/prices/FITB/FITB_2013.parquet',
#  '../../05_src/data/prices/KMI/KMI_2019.parquet',
#  '../../05_src/data/prices/KMI/KMI_2018.parquet',
#  '../../05_src/data/prices/KMI/KMI_2011.parquet',
#  '../../05_src/data/prices/KMI/KMI_2013.parquet',
#  '../../05_src/data/prices/KMI/KMI_2012.parquet',
#  '../../05_src/data/prices/KMI/KMI_2024.parquet',
#  '../../05_src/data/prices/KMI/KMI_2021.parquet',
#  '../../05_src/data/prices/KMI/KMI_2017.parquet',
#  '../../05_src/data/prices/KMI/KMI_2016.parquet',
#  '../../05_src/data/prices/KMI/KMI_2020.parquet',
#  '../../05_src/data/prices/KMI/KMI_2014.parquet',
#  '../../05_src/data/prices/KMI/KMI_2022.parquet',
#  '../../05_src/data/prices/KMI/KMI_2023.parquet',
#  '../../05_src/data/prices/KMI/KMI_2015.parquet',
#  '../../05_src/data/prices/UBER/UBER_2019.parquet',
#  '../../05_src/data/prices/UBER/UBER_2024.parquet',
#  '../../05_src/data/prices/UBER/UBER_2020.parquet',
#  '../../05_src/data/prices/UBER/UBER_2021.parquet',
#  '../../05_src/data/prices/UBER/UBER_2023.parquet',
#  '../../05_src/data/prices/UBER/UBER_2022.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2006.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2016.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2020.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2021.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2017.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2007.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2023.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2005.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2015.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2014.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2004.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2022.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2018.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2008.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2001.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2011.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2010.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2000.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2009.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2019.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2002.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2012.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2024.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2013.parquet',
#  '../../05_src/data/prices/SPGI/SPGI_2003.parquet',
#  '../../05_src/data/prices/ALLE/ALLE_2016.parquet',
#  '../../05_src/data/prices/ALLE/ALLE_2020.parquet',
#  '../../05_src/data/prices/ALLE/ALLE_2021.parquet',
#  '../../05_src/data/prices/ALLE/ALLE_2017.parquet',
#  '../../05_src/data/prices/ALLE/ALLE_2023.parquet',
#  '../../05_src/data/prices/ALLE/ALLE_2015.parquet',
#  '../../05_src/data/prices/ALLE/ALLE_2014.parquet',
#  '../../05_src/data/prices/ALLE/ALLE_2022.parquet',
#  '../../05_src/data/prices/ALLE/ALLE_2018.parquet',
#  '../../05_src/data/prices/ALLE/ALLE_2019.parquet',
#  '../../05_src/data/prices/ALLE/ALLE_2024.parquet',
#  '../../05_src/data/prices/ALLE/ALLE_2013.parquet',
#  '../../05_src/data/prices/SYK/SYK_2020.parquet',
#  '../../05_src/data/prices/SYK/SYK_2006.parquet',
#  '../../05_src/data/prices/SYK/SYK_2016.parquet',
#  '../../05_src/data/prices/SYK/SYK_2017.parquet',
#  '../../05_src/data/prices/SYK/SYK_2007.parquet',
#  '../../05_src/data/prices/SYK/SYK_2021.parquet',
#  '../../05_src/data/prices/SYK/SYK_2005.parquet',
#  '../../05_src/data/prices/SYK/SYK_2015.parquet',
#  '../../05_src/data/prices/SYK/SYK_2023.parquet',
#  '../../05_src/data/prices/SYK/SYK_2022.parquet',
#  '../../05_src/data/prices/SYK/SYK_2014.parquet',
#  '../../05_src/data/prices/SYK/SYK_2004.parquet',
#  '../../05_src/data/prices/SYK/SYK_2001.parquet',
#  '../../05_src/data/prices/SYK/SYK_2011.parquet',
#  '../../05_src/data/prices/SYK/SYK_2018.parquet',
#  '../../05_src/data/prices/SYK/SYK_2008.parquet',
#  '../../05_src/data/prices/SYK/SYK_2009.parquet',
#  '../../05_src/data/prices/SYK/SYK_2019.parquet',
#  '../../05_src/data/prices/SYK/SYK_2010.parquet',
#  '../../05_src/data/prices/SYK/SYK_2000.parquet',
#  '../../05_src/data/prices/SYK/SYK_2024.parquet',
#  '../../05_src/data/prices/SYK/SYK_2002.parquet',
#  '../../05_src/data/prices/SYK/SYK_2012.parquet',
#  '../../05_src/data/prices/SYK/SYK_2013.parquet',
#  '../../05_src/data/prices/SYK/SYK_2003.parquet',
#  '../../05_src/data/prices/MMC/MMC_2003.parquet',
#  '../../05_src/data/prices/MMC/MMC_2013.parquet',
#  '../../05_src/data/prices/MMC/MMC_2024.parquet',
#  '../../05_src/data/prices/MMC/MMC_2012.parquet',
#  '../../05_src/data/prices/MMC/MMC_2002.parquet',
#  '../../05_src/data/prices/MMC/MMC_2019.parquet',
#  '../../05_src/data/prices/MMC/MMC_2009.parquet',
#  '../../05_src/data/prices/MMC/MMC_2000.parquet',
#  '../../05_src/data/prices/MMC/MMC_2010.parquet',
#  '../../05_src/data/prices/MMC/MMC_2011.parquet',
#  '../../05_src/data/prices/MMC/MMC_2001.parquet',
#  '../../05_src/data/prices/MMC/MMC_2008.parquet',
#  '../../05_src/data/prices/MMC/MMC_2018.parquet',
#  '../../05_src/data/prices/MMC/MMC_2022.parquet',
#  '../../05_src/data/prices/MMC/MMC_2004.parquet',
#  '../../05_src/data/prices/MMC/MMC_2014.parquet',
#  '../../05_src/data/prices/MMC/MMC_2015.parquet',
#  '../../05_src/data/prices/MMC/MMC_2005.parquet',
#  '../../05_src/data/prices/MMC/MMC_2023.parquet',
#  '../../05_src/data/prices/MMC/MMC_2007.parquet',
#  '../../05_src/data/prices/MMC/MMC_2017.parquet',
#  '../../05_src/data/prices/MMC/MMC_2021.parquet',
#  '../../05_src/data/prices/MMC/MMC_2020.parquet',
#  '../../05_src/data/prices/MMC/MMC_2016.parquet',
#  '../../05_src/data/prices/MMC/MMC_2006.parquet',
#  '../../05_src/data/prices/MPWR/MPWR_2010.parquet',
#  '../../05_src/data/prices/MPWR/MPWR_2019.parquet',
#  '../../05_src/data/prices/MPWR/MPWR_2009.parquet',
#  '../../05_src/data/prices/MPWR/MPWR_2008.parquet',
#  '../../05_src/data/prices/MPWR/MPWR_2018.parquet',
#  '../../05_src/data/prices/MPWR/MPWR_2011.parquet',
#  '../../05_src/data/prices/MPWR/MPWR_2013.parquet',
#  '../../05_src/data/prices/MPWR/MPWR_2012.parquet',
#  '../../05_src/data/prices/MPWR/MPWR_2024.parquet',
#  '../../05_src/data/prices/MPWR/MPWR_2021.parquet',
#  '../../05_src/data/prices/MPWR/MPWR_2007.parquet',
#  '../../05_src/data/prices/MPWR/MPWR_2017.parquet',
#  '../../05_src/data/prices/MPWR/MPWR_2016.parquet',
#  '../../05_src/data/prices/MPWR/MPWR_2006.parquet',
#  '../../05_src/data/prices/MPWR/MPWR_2020.parquet',
#  '../../05_src/data/prices/MPWR/MPWR_2004.parquet',
#  '../../05_src/data/prices/MPWR/MPWR_2014.parquet',
#  '../../05_src/data/prices/MPWR/MPWR_2022.parquet',
#  '../../05_src/data/prices/MPWR/MPWR_2023.parquet',
#  '../../05_src/data/prices/MPWR/MPWR_2015.parquet',
#  '../../05_src/data/prices/MPWR/MPWR_2005.parquet',
#  '../../05_src/data/prices/DXCM/DXCM_2016.parquet',
#  '../../05_src/data/prices/DXCM/DXCM_2006.parquet',
#  '../../05_src/data/prices/DXCM/DXCM_2020.parquet',
#  '../../05_src/data/prices/DXCM/DXCM_2021.parquet',
#  '../../05_src/data/prices/DXCM/DXCM_2007.parquet',
#  '../../05_src/data/prices/DXCM/DXCM_2017.parquet',
#  '../../05_src/data/prices/DXCM/DXCM_2023.parquet',
#  '../../05_src/data/prices/DXCM/DXCM_2015.parquet',
#  '../../05_src/data/prices/DXCM/DXCM_2005.parquet',
#  '../../05_src/data/prices/DXCM/DXCM_2014.parquet',
#  '../../05_src/data/prices/DXCM/DXCM_2022.parquet',
#  '../../05_src/data/prices/DXCM/DXCM_2008.parquet',
#  '../../05_src/data/prices/DXCM/DXCM_2018.parquet',
#  '../../05_src/data/prices/DXCM/DXCM_2011.parquet',
#  '../../05_src/data/prices/DXCM/DXCM_2010.parquet',
#  '../../05_src/data/prices/DXCM/DXCM_2019.parquet',
#  '../../05_src/data/prices/DXCM/DXCM_2009.parquet',
#  '../../05_src/data/prices/DXCM/DXCM_2012.parquet',
#  '../../05_src/data/prices/DXCM/DXCM_2024.parquet',
#  '../../05_src/data/prices/DXCM/DXCM_2013.parquet',
#  '../../05_src/data/prices/PEP/PEP_2024.parquet',
#  '../../05_src/data/prices/PEP/PEP_2012.parquet',
#  '../../05_src/data/prices/PEP/PEP_2002.parquet',
#  '../../05_src/data/prices/PEP/PEP_2003.parquet',
#  '../../05_src/data/prices/PEP/PEP_2013.parquet',
#  '../../05_src/data/prices/PEP/PEP_2011.parquet',
#  '../../05_src/data/prices/PEP/PEP_2001.parquet',
#  '../../05_src/data/prices/PEP/PEP_2008.parquet',
#  '../../05_src/data/prices/PEP/PEP_2018.parquet',
#  '../../05_src/data/prices/PEP/PEP_2019.parquet',
#  '../../05_src/data/prices/PEP/PEP_2009.parquet',
#  '../../05_src/data/prices/PEP/PEP_2000.parquet',
#  '../../05_src/data/prices/PEP/PEP_2010.parquet',
#  '../../05_src/data/prices/PEP/PEP_2015.parquet',
#  '../../05_src/data/prices/PEP/PEP_2005.parquet',
#  '../../05_src/data/prices/PEP/PEP_2023.parquet',
#  '../../05_src/data/prices/PEP/PEP_2022.parquet',
#  '../../05_src/data/prices/PEP/PEP_2004.parquet',
#  '../../05_src/data/prices/PEP/PEP_2014.parquet',
#  '../../05_src/data/prices/PEP/PEP_2020.parquet',
#  '../../05_src/data/prices/PEP/PEP_2016.parquet',
#  '../../05_src/data/prices/PEP/PEP_2006.parquet',
#  '../../05_src/data/prices/PEP/PEP_2007.parquet',
#  '../../05_src/data/prices/PEP/PEP_2017.parquet',
#  '../../05_src/data/prices/PEP/PEP_2021.parquet',
#  '../../05_src/data/prices/FRT/FRT_2005.parquet',
#  '../../05_src/data/prices/FRT/FRT_2015.parquet',
#  '../../05_src/data/prices/FRT/FRT_2023.parquet',
#  '../../05_src/data/prices/FRT/FRT_2022.parquet',
#  '../../05_src/data/prices/FRT/FRT_2014.parquet',
#  '../../05_src/data/prices/FRT/FRT_2004.parquet',
#  '../../05_src/data/prices/FRT/FRT_2020.parquet',
#  '../../05_src/data/prices/FRT/FRT_2006.parquet',
#  '../../05_src/data/prices/FRT/FRT_2016.parquet',
#  '../../05_src/data/prices/FRT/FRT_2017.parquet',
#  '../../05_src/data/prices/FRT/FRT_2007.parquet',
#  '../../05_src/data/prices/FRT/FRT_2021.parquet',
#  '../../05_src/data/prices/FRT/FRT_2024.parquet',
#  '../../05_src/data/prices/FRT/FRT_2002.parquet',
#  '../../05_src/data/prices/FRT/FRT_2012.parquet',
#  '../../05_src/data/prices/FRT/FRT_2013.parquet',
#  '../../05_src/data/prices/FRT/FRT_2003.parquet',
#  '../../05_src/data/prices/FRT/FRT_2001.parquet',
#  '../../05_src/data/prices/FRT/FRT_2011.parquet',
#  '../../05_src/data/prices/FRT/FRT_2018.parquet',
#  '../../05_src/data/prices/FRT/FRT_2008.parquet',
#  '../../05_src/data/prices/FRT/FRT_2009.parquet',
#  '../../05_src/data/prices/FRT/FRT_2019.parquet',
#  '../../05_src/data/prices/FRT/FRT_2010.parquet',
#  '../../05_src/data/prices/FRT/FRT_2000.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2009.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2019.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2010.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2000.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2001.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2011.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2018.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2008.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2013.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2003.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2024.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2002.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2012.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2017.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2007.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2021.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2020.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2006.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2016.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2022.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2014.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2004.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2005.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2015.parquet',
#  '../../05_src/data/prices/SNPS/SNPS_2023.parquet',
#  '../../05_src/data/prices/PLD/PLD_2024.parquet',
#  '../../05_src/data/prices/PLD/PLD_2002.parquet',
#  '../../05_src/data/prices/PLD/PLD_2012.parquet',
#  '../../05_src/data/prices/PLD/PLD_2013.parquet',
#  '../../05_src/data/prices/PLD/PLD_2003.parquet',
#  '../../05_src/data/prices/PLD/PLD_2001.parquet',
#  '../../05_src/data/prices/PLD/PLD_2011.parquet',
#  '../../05_src/data/prices/PLD/PLD_2018.parquet',
#  '../../05_src/data/prices/PLD/PLD_2008.parquet',
#  '../../05_src/data/prices/PLD/PLD_2009.parquet',
#  '../../05_src/data/prices/PLD/PLD_2019.parquet',
#  '../../05_src/data/prices/PLD/PLD_2010.parquet',
#  '../../05_src/data/prices/PLD/PLD_2000.parquet',
#  '../../05_src/data/prices/PLD/PLD_2005.parquet',
#  '../../05_src/data/prices/PLD/PLD_2015.parquet',
#  '../../05_src/data/prices/PLD/PLD_2023.parquet',
#  '../../05_src/data/prices/PLD/PLD_2022.parquet',
#  '../../05_src/data/prices/PLD/PLD_2014.parquet',
#  '../../05_src/data/prices/PLD/PLD_2004.parquet',
#  '../../05_src/data/prices/PLD/PLD_2020.parquet',
#  '../../05_src/data/prices/PLD/PLD_2006.parquet',
#  '../../05_src/data/prices/PLD/PLD_2016.parquet',
#  '../../05_src/data/prices/PLD/PLD_2017.parquet',
#  '../../05_src/data/prices/PLD/PLD_2007.parquet',
#  '../../05_src/data/prices/PLD/PLD_2021.parquet',
#  '../../05_src/data/prices/GOOG/GOOG_2012.parquet',
#  '../../05_src/data/prices/GOOG/GOOG_2024.parquet',
#  '../../05_src/data/prices/GOOG/GOOG_2013.parquet',
#  '../../05_src/data/prices/GOOG/GOOG_2008.parquet',
#  '../../05_src/data/prices/GOOG/GOOG_2018.parquet',
#  '../../05_src/data/prices/GOOG/GOOG_2011.parquet',
#  '../../05_src/data/prices/GOOG/GOOG_2010.parquet',
#  '../../05_src/data/prices/GOOG/GOOG_2019.parquet',
#  '../../05_src/data/prices/GOOG/GOOG_2009.parquet',
#  '../../05_src/data/prices/GOOG/GOOG_2023.parquet',
#  '../../05_src/data/prices/GOOG/GOOG_2015.parquet',
#  '../../05_src/data/prices/GOOG/GOOG_2005.parquet',
#  '../../05_src/data/prices/GOOG/GOOG_2004.parquet',
#  '../../05_src/data/prices/GOOG/GOOG_2014.parquet',
#  '../../05_src/data/prices/GOOG/GOOG_2022.parquet',
#  '../../05_src/data/prices/GOOG/GOOG_2016.parquet',
#  '../../05_src/data/prices/GOOG/GOOG_2006.parquet',
#  '../../05_src/data/prices/GOOG/GOOG_2020.parquet',
#  '../../05_src/data/prices/GOOG/GOOG_2021.parquet',
#  '../../05_src/data/prices/GOOG/GOOG_2007.parquet',
#  '../../05_src/data/prices/GOOG/GOOG_2017.parquet',
#  '../../05_src/data/prices/MMM/MMM_2023.parquet',
#  '../../05_src/data/prices/MMM/MMM_2015.parquet',
#  '../../05_src/data/prices/MMM/MMM_2005.parquet',
#  '../../05_src/data/prices/MMM/MMM_2004.parquet',
#  '../../05_src/data/prices/MMM/MMM_2014.parquet',
#  '../../05_src/data/prices/MMM/MMM_2022.parquet',
#  '../../05_src/data/prices/MMM/MMM_2016.parquet',
#  '../../05_src/data/prices/MMM/MMM_2006.parquet',
#  '../../05_src/data/prices/MMM/MMM_2020.parquet',
#  '../../05_src/data/prices/MMM/MMM_2021.parquet',
#  '../../05_src/data/prices/MMM/MMM_2007.parquet',
#  '../../05_src/data/prices/MMM/MMM_2017.parquet',
#  '../../05_src/data/prices/MMM/MMM_2012.parquet',
#  '../../05_src/data/prices/MMM/MMM_2002.parquet',
#  '../../05_src/data/prices/MMM/MMM_2024.parquet',
#  '../../05_src/data/prices/MMM/MMM_2003.parquet',
#  '../../05_src/data/prices/MMM/MMM_2013.parquet',
#  '../../05_src/data/prices/MMM/MMM_2008.parquet',
#  '../../05_src/data/prices/MMM/MMM_2018.parquet',
#  '../../05_src/data/prices/MMM/MMM_2011.parquet',
#  '../../05_src/data/prices/MMM/MMM_2001.parquet',
#  '../../05_src/data/prices/MMM/MMM_2000.parquet',
#  '../../05_src/data/prices/MMM/MMM_2010.parquet',
#  '../../05_src/data/prices/MMM/MMM_2019.parquet',
#  '../../05_src/data/prices/MMM/MMM_2009.parquet',
#  '../../05_src/data/prices/EMN/EMN_2018.parquet',
#  '../../05_src/data/prices/EMN/EMN_2008.parquet',
#  '../../05_src/data/prices/EMN/EMN_2001.parquet',
#  '../../05_src/data/prices/EMN/EMN_2011.parquet',
#  '../../05_src/data/prices/EMN/EMN_2010.parquet',
#  '../../05_src/data/prices/EMN/EMN_2000.parquet',
#  '../../05_src/data/prices/EMN/EMN_2009.parquet',
#  '../../05_src/data/prices/EMN/EMN_2019.parquet',
#  '../../05_src/data/prices/EMN/EMN_2002.parquet',
#  '../../05_src/data/prices/EMN/EMN_2012.parquet',
#  '../../05_src/data/prices/EMN/EMN_2024.parquet',
#  '../../05_src/data/prices/EMN/EMN_2013.parquet',
#  '../../05_src/data/prices/EMN/EMN_2003.parquet',
#  '../../05_src/data/prices/EMN/EMN_2006.parquet',
#  '../../05_src/data/prices/EMN/EMN_2016.parquet',
#  '../../05_src/data/prices/EMN/EMN_2020.parquet',
#  '../../05_src/data/prices/EMN/EMN_2021.parquet',
#  '../../05_src/data/prices/EMN/EMN_2017.parquet',
#  '../../05_src/data/prices/EMN/EMN_2007.parquet',
#  '../../05_src/data/prices/EMN/EMN_2023.parquet',
#  '../../05_src/data/prices/EMN/EMN_2005.parquet',
#  '../../05_src/data/prices/EMN/EMN_2015.parquet',
#  '../../05_src/data/prices/EMN/EMN_2014.parquet',
#  '../../05_src/data/prices/EMN/EMN_2004.parquet',
#  '../../05_src/data/prices/EMN/EMN_2022.parquet',
#  '../../05_src/data/prices/NXPI/NXPI_2013.parquet',
#  '../../05_src/data/prices/NXPI/NXPI_2012.parquet',
#  '../../05_src/data/prices/NXPI/NXPI_2024.parquet',
#  '../../05_src/data/prices/NXPI/NXPI_2010.parquet',
#  '../../05_src/data/prices/NXPI/NXPI_2019.parquet',
#  '../../05_src/data/prices/NXPI/NXPI_2018.parquet',
#  '../../05_src/data/prices/NXPI/NXPI_2011.parquet',
#  '../../05_src/data/prices/NXPI/NXPI_2014.parquet',
#  '../../05_src/data/prices/NXPI/NXPI_2022.parquet',
#  '../../05_src/data/prices/NXPI/NXPI_2023.parquet',
#  '../../05_src/data/prices/NXPI/NXPI_2015.parquet',
#  '../../05_src/data/prices/NXPI/NXPI_2021.parquet',
#  '../../05_src/data/prices/NXPI/NXPI_2017.parquet',
#  '../../05_src/data/prices/NXPI/NXPI_2016.parquet',
#  '../../05_src/data/prices/NXPI/NXPI_2020.parquet',
#  '../../05_src/data/prices/PCG/PCG_2018.parquet',
#  '../../05_src/data/prices/PCG/PCG_2008.parquet',
#  '../../05_src/data/prices/PCG/PCG_2001.parquet',
#  '../../05_src/data/prices/PCG/PCG_2011.parquet',
#  '../../05_src/data/prices/PCG/PCG_2010.parquet',
#  '../../05_src/data/prices/PCG/PCG_2000.parquet',
#  '../../05_src/data/prices/PCG/PCG_2009.parquet',
#  '../../05_src/data/prices/PCG/PCG_2019.parquet',
#  '../../05_src/data/prices/PCG/PCG_2002.parquet',
#  '../../05_src/data/prices/PCG/PCG_2012.parquet',
#  '../../05_src/data/prices/PCG/PCG_2024.parquet',
#  '../../05_src/data/prices/PCG/PCG_2013.parquet',
#  '../../05_src/data/prices/PCG/PCG_2003.parquet',
#  '../../05_src/data/prices/PCG/PCG_2006.parquet',
#  ...]

# %% [markdown]
# For each ticker and using Dask, do the following:
#
# + Add lags for variables Close and Adj_Close.
# + Add returns based on Adjusted Close:
#
#     - `returns`: (Adj Close / Adj Close_lag) - 1
#
# + Add the following range:
#
#     - `hi_lo_range`: this is the day's High minus Low.
#
# + Assign the result to `dd_feat`.
#
# (4 pt)

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "*/*.parquet"))
dd_px = dd.read_parquet(parquet_files).set_index("ticker")
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[16], line 4
#       1 from glob import glob
#       3 parquet_files = glob(os.path.join(PRICE_DATA, "*/*.parquet"))
# ----> 4 dd_px = dd.read_parquet(parquet_files).set_index("ticker")
#
# File /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/dask_expr/_collection.py:4616, in read_parquet(path, columns, filters, categories, index, storage_options, dtype_backend, calculate_divisions, ignore_metadata_file, metadata_task_size, split_row_groups, blocksize, aggregate_files, parquet_file_extension, filesystem, engine, **kwargs)
#    4612         if op == "in" and not isinstance(val, (set, list, tuple)):
#    4613             raise TypeError("Value of 'in' filter must be a list, set or tuple.")
#    4615 return new_collection(
# -> 4616     ReadParquet(
#    4617         path,
#    4618         columns=_convert_to_list(columns),
#    4619         filters=filters,
#    4620         categories=categories,
#    4621         index=index,
#    4622         storage_options=storage_options,
#    4623         calculate_divisions=calculate_divisions,
#    4624         ignore_metadata_file=ignore_metadata_file,
#    4625         metadata_task_size=metadata_task_size,
#    4626         split_row_groups=split_row_groups,
#    4627         blocksize=blocksize,
#    4628         aggregate_files=aggregate_files,
#    4629         parquet_file_extension=parquet_file_extension,
#    4630         filesystem=filesystem,
#    4631         engine=_set_parquet_engine(engine),
#    4632         kwargs=kwargs,
#    4633         _series=isinstance(columns, str),
#    4634     )
#    4635 )
#
# File /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/dask_expr/_core.py:43, in Expr.__new__(cls, *args, **kwargs)
#      41 inst = object.__new__(cls)
#      42 inst.operands = [_unpack_collections(o) for o in operands]
# ---> 43 _name = inst._name
#      44 if _name in Expr._instances:
#      45     return Expr._instances[_name]
#
# File /opt/miniconda3/envs/dsi_participant/lib/python3.9/functools.py:993, in cached_property.__get__(self, instance, owner)
#     991 val = cache.get(self.attrname, _NOT_FOUND)
#     992 if val is _NOT_FOUND:
# --> 993     val = self.func(instance)
#     994     try:
#     995         cache[self.attrname] = val
#
# File /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/dask_expr/io/parquet.py:477, in ReadParquet._name(self)
#     472 @cached_property
#     473 def _name(self):
#     474     return (
#     475         funcname(type(self)).lower()
#     476         + "-"
# --> 477         + _tokenize_deterministic(self.checksum, *self.operands)
#     478     )
#
# File /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/dask_expr/io/parquet.py:482, in ReadParquet.checksum(self)
#     480 @property
#     481 def checksum(self):
# --> 482     return self._dataset_info["checksum"]
#
# File /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/dask_expr/io/parquet.py:549, in ReadParquet._dataset_info(self)
#     529 # Collect general dataset info
#     530 args = (
#     531     paths,
#     532     fs,
#    (...)
#     547     },
#     548 )
# --> 549 dataset_info = self.engine._collect_dataset_info(*args)
#     550 checksum = []
#     551 files_for_checksum = []
#
# File /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/dask/dataframe/io/parquet/arrow.py:1060, in ArrowDatasetEngine._collect_dataset_info(cls, paths, fs, categories, index, gather_statistics, filters, split_row_groups, blocksize, aggregate_files, ignore_metadata_file, metadata_task_size, parquet_file_extension, kwargs)
#    1058 # Final "catch-all" pyarrow.dataset call
#    1059 if ds is None:
# -> 1060     ds = pa_ds.dataset(
#    1061         paths,
#    1062         filesystem=_wrapped_fs(fs),
#    1063         **_processed_dataset_kwargs,
#    1064     )
#    1066 # Get file_frag sample and extract physical_schema
#    1067 try:
#
# File /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/pyarrow/dataset.py:785, in dataset(source, schema, format, filesystem, partitioning, partition_base_dir, exclude_invalid_files, ignore_prefixes)
#     783 elif isinstance(source, (tuple, list)):
#     784     if all(_is_path_like(elem) for elem in source):
# --> 785         return _filesystem_dataset(source, **kwargs)
#     786     elif all(isinstance(elem, Dataset) for elem in source):
#     787         return _union_dataset(source, **kwargs)
#
# File /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/pyarrow/dataset.py:463, in _filesystem_dataset(source, schema, filesystem, partitioning, format, partition_base_dir, exclude_invalid_files, selector_ignore_prefixes)
#     460 partitioning = _ensure_partitioning(partitioning)
#     462 if isinstance(source, (list, tuple)):
# --> 463     fs, paths_or_selector = _ensure_multiple_sources(source, filesystem)
#     464 else:
#     465     fs, paths_or_selector = _ensure_single_source(source, filesystem)
#
# File /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/pyarrow/dataset.py:384, in _ensure_multiple_sources(paths, filesystem)
#     382     raise FileNotFoundError(info.path)
#     383 elif file_type == FileType.Directory:
# --> 384     raise IsADirectoryError(
#     385         'Path {} points to a directory, but only file paths are '
#     386         'supported. To construct a nested or union dataset pass '
#     387         'a list of dataset objects instead.'.format(info.path)
#     388     )
#     389 else:
#     390     raise IOError(
#     391         'Path {} exists but its type is unknown (could be a '
#     392         'special file such as a Unix socket or character device, '
#     393         'or Windows NUL / CON / ...)'.format(info.path)
#     394     )
#
# IsADirectoryError: Path /Users/cecilyli/Documents/DSI/scaling_to_production/02_activities/assignments/../../05_src/data/prices/A/A_2000.parquet points to a directory, but only file paths are supported. To construct a nested or union dataset pass a list of dataset objects instead.

# %%
# Write your code below.


import numpy as np
dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(
    lambda x: x.assign(Adj_Close = x['Close'].shift(1)), 
    lambda y: y(Adj_Close_lag = y['Adj_Close'].shift(1))
).assign(
    returns = lambda x: x['Adj_Close']/x['Adj_Close_lag'] - 1
).assign(
    positive_return = lambda x: (x['returns'] > 0)*1
))

hi_lo_range = 

dd_feat =
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 5
#       1 # Write your code below.
#       4 import numpy as np
# ----> 5 dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(
#       6     lambda x: x.assign(Adj_Close = x['Close'].shift(1)),
#       7     lambda y: y(Adj_Close_lag = y['Adj_Close'].shift(1))
#       8 ).assign(
#       9     returns = lambda x: x['Adj_Close']/x['Adj_Close_lag'] - 1
#      10 ).assign(
#      11     positive_return = lambda x: (x['returns'] > 0)*1
#      12 ))
#
# NameError: name 'dd_px' is not defined

# %% [markdown]
# + Convert the Dask data frame to a pandas data frame.
# + Add a rolling average return calculation with a window of 10 days.
# + *Tip*: Consider using `.rolling(10).mean()`.
#
# (3 pt)

# %%
# Write your code below.
dd_px = dd_px.compute()

dd_px.rolling(10).mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Write your code below.
# ----> 2 dd_px = dd_px.compute()
#       4 dd_px.rolling(10).mean()
#
# NameError: name 'dd_px' is not defined

# %% [markdown]
# Please comment:
#
# + Was it necessary to convert to pandas to calculate the moving average return?
# + Would it have been better to do it in Dask? Why?
#
# (1 pt)

# %%
#No
#Dask is faster

# %% [markdown]
# ## Criteria
#
# The [rubric](./assignment_1_rubric_clean.xlsx) contains the criteria for grading.

# %% [markdown]
# ## Submission Information
#
# 🚨 **Please review our [Assignment Submission Guide](https://github.com/UofT-DSI/onboarding/blob/main/onboarding_documents/submissions.md)** 🚨 for detailed instructions on how to format, branch, and submit your work. Following these guidelines is crucial for your submissions to be evaluated correctly.
#
# ### Submission Parameters:
# * Submission Due Date: `HH:MM AM/PM - DD/MM/YYYY`
# * The branch name for your repo should be: `assignment-1`
# * What to submit for this assignment:
#     * This Jupyter Notebook (assignment_1.ipynb) should be populated and should be the only change in your pull request.
# * What the pull request link should look like for this assignment: `https://github.com/<your_github_username>/production/pull/<pr_id>`
#     * Open a private window in your browser. Copy and paste the link to your pull request into the address bar. Make sure you can see your pull request properly. This helps the technical facilitator and learning support staff review your submission easily.
#
# Checklist:
# - [ ] Created a branch with the correct naming convention.
# - [ ] Ensured that the repository is public.
# - [ ] Reviewed the PR description guidelines and adhered to them.
# - [ ] Verify that the link is accessible in a private browser window.
#
# If you encounter any difficulties or have questions, please don't hesitate to reach out to our team via our Slack at `#cohort-3-help`. Our Technical Facilitators and Learning Support staff are here to help you navigate any challenges.
